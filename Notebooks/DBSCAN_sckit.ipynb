# %% [markdown]
# # DBSCAN

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
from sklearn.cluster import DBSCAN
plt.style.use('ggplot')
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %%
X,label = make_moons(n_samples=200,noise=0.1,random_state=19)
print(X[:5,])
# Out:
# [[ 0.28171457  0.91044406]
#  [ 0.8389241  -0.53005338]
#  [ 0.40915474  0.80944352]
#  [-0.98415213  0.13142155]
#  [ 1.15919021  0.4910425 ]]

# %%
model = DBSCAN(eps=0.25,min_samples=12).fit(X)

# %%
# print(model.labels_)

# %%
fig, ax = plt.subplots(figsize=(10,8))
sctr = ax.scatter(X[:, 0],X[:, 1],c=model.labels_,s=140,cmap=plt.cm.Set1)
fig.show()
# Out:
# /Users/sajivkamalakaran/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
